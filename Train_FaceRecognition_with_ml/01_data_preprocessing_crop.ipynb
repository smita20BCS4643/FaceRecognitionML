# %% [markdown]
# ### Step 1 : Crop faces and store in respective directory

# %%
#import library
import numpy as np # numerical python
import cv2
from glob import glob
import matplotlib.pyplot as plt

# %%
fpath = glob('./data/female/*.jpg') # this will return all images path in a list
mpath = glob('./data/male/*.jpg')

# %%
fpath
# Out:
# ['./data/female\\female_000000.jpg',
#  './data/female\\female_000001.jpg',
#  './data/female\\female_000002.jpg',
#  './data/female\\female_000003.jpg',
#  './data/female\\female_000004.jpg',
#  './data/female\\female_000005.jpg',
#  './data/female\\female_000006.jpg',
#  './data/female\\female_000007.jpg',
#  './data/female\\female_000008.jpg',
#  './data/female\\female_000009.jpg',
#  './data/female\\female_000010.jpg',
#  './data/female\\female_000011.jpg',
#  './data/female\\female_000012.jpg',
#  './data/female\\female_000013.jpg',
#  './data/female\\female_000014.jpg',
#  './data/female\\female_000018.jpg',
#  './data/female\\female_000019.jpg',
#  './data/female\\female_000020.jpg',
#  './data/female\\female_000021.jpg',
#  './data/female\\female_000024.jpg',
#  './data/female\\female_000025.jpg',
#  './data/female\\female_000026.jpg',
#  './data/female\\female_000028.jpg',
#  './data/female\\female_000030.jpg',
#  './data/female\\female_000031.jpg',
# ...

# %%
print('number of image in Females folder= ',len(fpath))
print('number of image in Males folder= ',len(mpath))
# Out:
# number of image in Females folder=  4762
# number of image in Males folder=  5399

# %%
### Step -1 Read Image and convert to RGB
img = cv2.imread(fpath[0]) #read image in BGR
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) # this step will convert image from BGR to RGB)

### Step -2 Apply Haar Cascade Classifier

haar = cv2.CascadeClassifier('./model/haarcascade_frontalface_default - Copy.xml')
gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB)
faces_list = haar.detectMultiScale(gray,1.5,5)
print(faces_list)
for x,y,w,h in faces_list:
    cv2.rectangle (img_rgb,(x,y),(x+w,y+h),(255,255,0),2)

### Step -3 Crop Face

roi = img_rgb[y: y+h, x:x+w]
plt.imshow(roi)
plt.axis('off')
plt.show()

### Step -4 Save Image
# Out:
# [[ 86  86 273 273]]

# %%
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Crop all Female images

# %%
for i in range(len(fpath)):
    try:
        ### Step -1 Read Image and convert to RGB
        img = cv2.imread(fpath[0]) #read image in BGR
        img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) # this step will convert image from BGR to RGB)

### Step -2 Apply Haar Cascade Classifier

        haar = cv2.CascadeClassifier('./model/haarcascade_frontalface_default - Copy.xml')
        gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB)
        faces_list = haar.detectMultiScale(gray,1.5,5)
        print(faces_list)
        for x,y,w,h in faces_list:
            cv2.rectangle (img_rgb,(x,y),(x+w,y+h),(255,255,0),2)

### Step -3 Crop Face

        roi = img_rgb[y: y+h, x:x+w]


### Step -4 Save Image
  
        cv2.imwrite('./crop_data/female/female_{i}.jpg',roi)
        print('Image successfully Processed')
    except:
        print('Unable to process the image')
# Out:
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# Image successfully Processed
# [[ 86  86 273 273]]
# ...
